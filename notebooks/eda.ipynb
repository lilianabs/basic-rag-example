# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('../data/raw/FAQs_Evaluacion_LLMs.xlsx')

# %%
df = df.rename(columns={'Title': 'question', 'Final response': 'answer'})

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   question  39 non-null     str
#  1   answer    39 non-null     str
# dtypes: str(2)
# memory usage: 756.0 bytes

# %%
df['answer_len'] = df['answer'].apply(len)

# %%
df.head()
# Out:
#                                             question  \
# 0  ¿Qué procedimiento debo seguir para contratar ...
# 1  ¿Cuál es el procesos para contratar una cuenta...
# 2  ¿Cuáles son los requisitos para contratar una ...
# 3  ¿Qué documentos debo presentar para contratar ...
# 4  ¿Qué procedimiento debo seguir para la contrat...
#
#                                               answer  answer_len
# 0  Para contratar la Tarjeta Instantánea Definiti...         771
# 1  Para adquirir una cuenta Link Card debes segui...         233
# 2  Para poder contratar la Tarjeta de Crédito Edu...         753
# 3  Para contratar la Tarjeta de Crédito CREA BBVA...         779
# 4  Para contratar la Tarjeta Instantánea Definiti...         759

# %%
print("Min len: ",df['answer_len'].min())
print("Max len: ",df['answer_len'].max())
# Out:
# Min len:  233
# Max len:  874

# %%
sns.displot(df['answer_len'], kde=False)
